# %% [markdown]
# Introduction
#  Python is a general purpose high level programming language.
#  Python was developed by Guido Van Rossam in 1989 while working at National
# Research Institute at Netherlands.
#  But officially Python was made available to public in 1991. The official Date of Birth for
# Python is : Feb 20th 1991.
#  Python is recommended as first programming language for beginners.

# %%
a = 10
b = 20

# %%
id(a)
# Out:
# 1408000092752

# %%
id(b)
# Out:
# 1408000093072

# %%
b = 10

# %%
id(b)
# Out:
# 1408000092752

# %%
_tUYTtal123 = 10

# %%
a = 10

# %%
A = 12

# %%
if = 43
# Out:
#   File "<ipython-input-20-7e0bc8c089e1>", line 1
#     if = 43
#        ^
# SyntaxError: invalid syntax

# %%
 import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  '__peg_parser__',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b = 10.12

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
c = 3+4j

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
d = 'satii'
print(type(d))
# Out:
# <class 'str'>

# %%
a=10
b=0o10
c=0X10
d=0B10

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 8
# 16
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %%
hex(10)
# Out:
# '0xa'

# %%
oct(10)
# Out:
# '0o12'

# %%
int(12)
# Out:
# 12

# %%
float(23)
# Out:
# 23.0

# %%
s="durga prasad"

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
s[0]
# Out:
# 'd'

# %%
s[4]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 's'

# %%
s[::]
# Out:
# 'dasarp agrud'

# %%
s[0:5:2]
# Out:
# 'dra'

# %%
s[200]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-64831a69ded9> in <module>
# ----> 1 s[200]
#
# IndexError: string index out of range

# %%
len(s)
# Out:
# 12

# %%
3*3
# Out:
# 9

# %%
s*3
# Out:
# 'durga prasaddurga prasaddurga prasad'

# %%
a = 12

# %%
b = '12'

# %%
c = int('S')
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-3dcaabff5247> in <module>
# ----> 1 c = int('S')
#       2 print(c)
#
# ValueError: invalid literal for int() with base 10: 'S'

# %%
oct(23)
# Out:
# '0b10111'

# %%
bool(None)
# Out:
# False

# %%
2+2
# Out:
# 4

# %%
3-2
# Out:
# 1

# %%
2*3
# Out:
# 6

# %%
a = 10
b=2

print('a+b=',a+b)
print('a-b=',a-b)
print('a*b=',a*b)
print('a/b=',a/b)
print('a//b=',a//b)
print('a%b=',a%b)
print('a**b=',a**b)
# Out:
# a+b= 12
# a-b= 8
# a*b= 20
# a/b= 5.0
# a//b= 5
# a%b= 0
# a**b= 100

# %%
8%3
# Out:
# 2

# %%
10**2
# Out:
# 100

# %%
2**3
# Out:
# 8

# %%
a=10
b=20
print("a > b is ",a>b)
print("a >= b is ",a>=b)
print("a < b is ",a<b)
print("a <= b is ",a<=b)
# Out:
# a > b is  False
# a >= b is  False
# a < b is  True
# a <= b is  True

# %%
a="Durga"
b="durga"
print("a > b is ",a > b)
print("a >= b is ",a>=b)
print("a < b is ",a<b)
# Out:
# a > b is  False
# a >= b is  False
# a < b is  True

# %%
ascii('a')
# Out:
# "'a'"

# %%
ord('A')
# Out:
# 65

# %%
10 == 10
# Out:
# False

# %%
a  = 10

# %%
a = a+10


a+=10

# %%
input()
# Out:
# 34
# '34'

# %%
input()
# Out:
# 23
# 23

# %%
a = int(input('enter nuber: '))
# Out:
# enter nuber: 12

# %%
a
# Out:
# 12

# %%
a = 10
b = 10

# %%
print(id(a))
print(id(b))
# Out:
# 1408000092752
# 1408000092752

# %%
a is b
# Out:
# True

# %%
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)
